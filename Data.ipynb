# %%
import pandas as pd
df = pd.read_csv("Datatest.csv")
print(df.to_string())
# Out:
#      Policy     Expiry Location State     Region InsuredValue Construction   BusinessType Earthquake Flood
# 0    100242   2-Jan-21    Urban    NY       East    1,617,630        Frame         Retail          N     N
# 1    100314   2-Jan-21    Urban    NY       East    8,678,500  Fire Resist      Apartment          Y     Y
# 2    100359   2-Jan-21    Rural    WI    Midwest    2,052,660        Frame        Farming          N     N
# 3    100315   3-Jan-21    Urban    NY       East   17,580,000        Frame      Apartment          Y     Y
# 4    100385   3-Jan-21    Urban    NY       East    1,925,000      Masonry    Hospitality          N     N
# 5    100388   4-Jan-21    Urban    IL    Midwest   12,934,500        Frame      Apartment          Y     Y
# 6    100358   5-Jan-21    Urban    WI    Midwest      928,300      Masonry    Office Bldg          N     N
# 7    100264   7-Jan-21    Rural    NY       East    2,219,900        Frame        Farming          N     N
# ...
