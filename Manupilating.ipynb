# %%
# Working with dataframes

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Datatest.csv")

# %%
df
# Out:
#     Policy     Expiry Location State   Region InsuredValue Construction  \
# 0   100242   2-Jan-21    Urban    NY     East          NaN        Frame
# 1   100314   2-Jan-21    Urban    NY     East    8,678,500  Fire Resist
# 2   100359   2-Jan-21    Rural    WI  Midwest    2,052,660        Frame
# 3   100315   3-Jan-21    Urban    NY     East   17,580,000        Frame
# 4   100385   3-Jan-21    Urban    NY     East    1,925,000      Masonry
# 5   100388   4-Jan-21    Urban    IL  Midwest   12,934,500        Frame
# 6   100358   5-Jan-21    Urban    WI  Midwest      928,300      Masonry
# 7   100264   7-Jan-21    Rural    NY     East    2,219,900        Frame
# 8   100265   7-Jan-21    Urban    NY     East   14,100,000        Frame
# 9   100357   8-Jan-21    Urban    NY     East    4,762,808      Masonry
# 10  100399   8-Jan-21    Urban    NY     East   13,925,190        Frame
# 11  100329   9-Jan-21    Urban    NY     East          NaN        Frame
# ...

# %%
df.dropna()
# Out:
#     Policy     Expiry Location State   Region InsuredValue Construction  \
# 1   100314   2-Jan-21    Urban    NY     East    8,678,500  Fire Resist
# 2   100359   2-Jan-21    Rural    WI  Midwest    2,052,660        Frame
# 3   100315   3-Jan-21    Urban    NY     East   17,580,000        Frame
# 4   100385   3-Jan-21    Urban    NY     East    1,925,000      Masonry
# 5   100388   4-Jan-21    Urban    IL  Midwest   12,934,500        Frame
# 6   100358   5-Jan-21    Urban    WI  Midwest      928,300      Masonry
# 7   100264   7-Jan-21    Rural    NY     East    2,219,900        Frame
# 8   100265   7-Jan-21    Urban    NY     East   14,100,000        Frame
# 9   100357   8-Jan-21    Urban    NY     East    4,762,808      Masonry
# 10  100399   8-Jan-21    Urban    NY     East   13,925,190        Frame
# 12  100429   9-Jan-21    Urban    WI  Midwest    4,036,000      Masonry
# 13  100441  10-Jan-21    Urban    NJ     East      472,800      Masonry
#
# ...

# %%
df.fillna(0)
# Out:
#     Policy     Expiry Location State   Region InsuredValue Construction  \
# 0   100242   2-Jan-21    Urban    NY     East            0        Frame
# 1   100314   2-Jan-21    Urban    NY     East    8,678,500  Fire Resist
# 2   100359   2-Jan-21    Rural    WI  Midwest    2,052,660        Frame
# 3   100315   3-Jan-21    Urban    NY     East   17,580,000        Frame
# 4   100385   3-Jan-21    Urban    NY     East    1,925,000      Masonry
# 5   100388   4-Jan-21    Urban    IL  Midwest   12,934,500        Frame
# 6   100358   5-Jan-21    Urban    WI  Midwest      928,300      Masonry
# 7   100264   7-Jan-21    Rural    NY     East    2,219,900        Frame
# 8   100265   7-Jan-21    Urban    NY     East   14,100,000        Frame
# 9   100357   8-Jan-21    Urban    NY     East    4,762,808      Masonry
# 10  100399   8-Jan-21    Urban    NY     East   13,925,190        Frame
# 11  100329   9-Jan-21    Urban    NY     East            0        Frame
# ...

# %%
df.fillna(method ='ffill')
# Out:
#     Policy     Expiry Location State   Region InsuredValue Construction  \
# 0   100242   2-Jan-21    Urban    NY     East          NaN        Frame
# 1   100314   2-Jan-21    Urban    NY     East    8,678,500  Fire Resist
# 2   100359   2-Jan-21    Rural    WI  Midwest    2,052,660        Frame
# 3   100315   3-Jan-21    Urban    NY     East   17,580,000        Frame
# 4   100385   3-Jan-21    Urban    NY     East    1,925,000      Masonry
# 5   100388   4-Jan-21    Urban    IL  Midwest   12,934,500        Frame
# 6   100358   5-Jan-21    Urban    WI  Midwest      928,300      Masonry
# 7   100264   7-Jan-21    Rural    NY     East    2,219,900        Frame
# 8   100265   7-Jan-21    Urban    NY     East   14,100,000        Frame
# 9   100357   8-Jan-21    Urban    NY     East    4,762,808      Masonry
# 10  100399   8-Jan-21    Urban    NY     East   13,925,190        Frame
# 11  100329   9-Jan-21    Urban    NY     East   13,925,190        Frame
# ...

# %%
df.fillna(method ='bfill')
# Out:
#     Policy     Expiry Location State   Region InsuredValue Construction  \
# 0   100242   2-Jan-21    Urban    NY     East    8,678,500        Frame
# 1   100314   2-Jan-21    Urban    NY     East    8,678,500  Fire Resist
# 2   100359   2-Jan-21    Rural    WI  Midwest    2,052,660        Frame
# 3   100315   3-Jan-21    Urban    NY     East   17,580,000        Frame
# 4   100385   3-Jan-21    Urban    NY     East    1,925,000      Masonry
# 5   100388   4-Jan-21    Urban    IL  Midwest   12,934,500        Frame
# 6   100358   5-Jan-21    Urban    WI  Midwest      928,300      Masonry
# 7   100264   7-Jan-21    Rural    NY     East    2,219,900        Frame
# 8   100265   7-Jan-21    Urban    NY     East   14,100,000        Frame
# 9   100357   8-Jan-21    Urban    NY     East    4,762,808      Masonry
# 10  100399   8-Jan-21    Urban    NY     East   13,925,190        Frame
# 11  100329   9-Jan-21    Urban    NY     East    4,036,000        Frame
# ...

# %%
df
# Out:
#     Policy     Expiry Location State   Region InsuredValue Construction  \
# 0   100242   2-Jan-21    Urban    NY     East          NaN        Frame
# 1   100314   2-Jan-21    Urban    NY     East    8,678,500  Fire Resist
# 2   100359   2-Jan-21    Rural    WI  Midwest    2,052,660        Frame
# 3   100315   3-Jan-21    Urban    NY     East   17,580,000        Frame
# 4   100385   3-Jan-21    Urban    NY     East    1,925,000      Masonry
# 5   100388   4-Jan-21    Urban    IL  Midwest   12,934,500        Frame
# 6   100358   5-Jan-21    Urban    WI  Midwest      928,300      Masonry
# 7   100264   7-Jan-21    Rural    NY     East    2,219,900        Frame
# 8   100265   7-Jan-21    Urban    NY     East   14,100,000        Frame
# 9   100357   8-Jan-21    Urban    NY     East    4,762,808      Masonry
# 10  100399   8-Jan-21    Urban    NY     East   13,925,190        Frame
# 11  100329   9-Jan-21    Urban    NY     East          NaN        Frame
# ...

# %%
df.fillna({
    'InsuredValue' : 555555
        
})
# Out:
#     Policy     Expiry Location State   Region InsuredValue Construction  \
# 0   100242   2-Jan-21    Urban    NY     East       555555        Frame
# 1   100314   2-Jan-21    Urban    NY     East    8,678,500  Fire Resist
# 2   100359   2-Jan-21    Rural    WI  Midwest    2,052,660        Frame
# 3   100315   3-Jan-21    Urban    NY     East   17,580,000        Frame
# 4   100385   3-Jan-21    Urban    NY     East    1,925,000      Masonry
# 5   100388   4-Jan-21    Urban    IL  Midwest   12,934,500        Frame
# 6   100358   5-Jan-21    Urban    WI  Midwest      928,300      Masonry
# 7   100264   7-Jan-21    Rural    NY     East    2,219,900        Frame
# 8   100265   7-Jan-21    Urban    NY     East   14,100,000        Frame
# 9   100357   8-Jan-21    Urban    NY     East    4,762,808      Masonry
# 10  100399   8-Jan-21    Urban    NY     East   13,925,190        Frame
# 11  100329   9-Jan-21    Urban    NY     East       555555        Frame
# ...
