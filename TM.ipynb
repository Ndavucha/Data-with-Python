# %%
#importing data

# %%
import pandas as pd

dataset = pd.read_csv ("THE WARM POOL - leads-tracking.csv") 
dataset.head()
# Out:
#                                                 Name        Date       Name.1  \
# 0                   Lead notification from Instapage  2022-08-01  Zhanbo Wang
# 1  New submission on HubSpot Form "TM Blog Genera...  2022-08-01      Douglas
# 2  New submission on HubSpot Form "TM Blog Genera...  2022-08-01        Yommy
# 3  New submission on HubSpot Form "TM Blog Crypto...  2022-08-01            B
# 4  New submission on HubSpot Form "TM Blog Crypto...  2022-08-01        Bryan
#
#   Source Medium Term Campaign  \
# 0    NaN    NaN  NaN      NaN
# 1    NaN    NaN  NaN      NaN
# 2    NaN    NaN  NaN      NaN
# 3    NaN    NaN  NaN      NaN
# 4    NaN    NaN  NaN      NaN
#
#                                             LinkedIn  Status utm_content  ...  \
# 0                 No LinkedIn profile for this email     NaN         NaN  ...
# 1                                No LinkedIn profile     NaN         NaN  ...
# ...

# %%
#Selecting Rows that have Certain Values for google and tiktok

# %%
google=dataset[dataset.Source == 'google']

# %%
google
# Out:
#                                   Name        Date                    Name.1  \
# 67    Lead notification from Instapage  2022-08-03                   Lorenzo
# 70    Lead notification from Instapage  2022-08-03                       Ian
# 71    Lead notification from Instapage  2022-08-03               Ho Tsz Chun
# 75    Lead notification from Instapage  2022-08-03                  Aliandro
# 76    Lead notification from Instapage  2022-08-03                      Gork
# ...                                ...         ...                       ...
# 1030  Lead notification from Instapage  2022-08-31                     Yanis
# 1031  Lead notification from Instapage  2022-08-31          Vitória Clemente
# 1032  Lead notification from Instapage  2022-08-31                   Monique
# 1033  Lead notification from Instapage  2022-08-31                    Matiqs
# 1035  Lead notification from Instapage  2022-08-31  Mohamad saidi Kamaruddin
#
# ...

# %%
tiktok = dataset[dataset.Source == "tiktok"]

# %%
tiktok
# Out:
#                                  Name        Date                Name.1  \
# 22   Lead notification from Instapage  2022-08-02                  Rama
# 50   Lead notification from Instapage  2022-08-02          Tekwe Oliver
# 51   Lead notification from Instapage  2022-08-02  Fontebo Oliver Tekwe
# 53   Lead notification from Instapage  2022-08-02         Bakar Patrick
# 54   Lead notification from Instapage  2022-08-02               Peoyame
# ..                                ...         ...                   ...
# 274  Lead notification from Instapage  2022-08-08          Ditulal Sahu
# 275  Lead notification from Instapage  2022-08-08             Md Mahbub
# 277  Lead notification from Instapage  2022-08-08             Chan Myae
# 279  Lead notification from Instapage  2022-08-08          Pradip Kumar
# 282  Lead notification from Instapage  2022-08-08             Ridoy Zxx
#
#      Source Medium Term     Campaign  \
# 22   tiktok    NaN  NaN          NaN
# ...
